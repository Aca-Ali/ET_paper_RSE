# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import lightgbm as lgb
import optuna
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

from IPython.display import clear_output
import warnings

warnings.filterwarnings('ignore')

# %%
Scenario = 'Scenario_B'
ML_model = 'LightGBM_001'

# %% [markdown]
# ## Model training

# %%
train_file_Bi1 = os.path.join(os.path.dirname(os.getcwd()),'6_Data_aggregation',
                             'US_Bi1_Hourly_ECT_PSNDVI_ETa.csv')  # Change to your training file path

train_file_Bi2 = os.path.join(os.path.dirname(os.getcwd()),'6_Data_aggregation',
                             'US_Bi2_Hourly_ECT_PSNDVI_ETa.csv')  # Change to your training file path

# Load the data; ensure that the timestamp column is parsed as dates.
Bi1_train_df = pd.read_csv(train_file_Bi1, index_col=0, parse_dates=[0])
Bi2_train_df = pd.read_csv(train_file_Bi2, index_col=0, parse_dates=[0])

train_df = pd.concat([Bi1_train_df, Bi2_train_df])

# Drop observations with nan NDVI values or ET_corr nan values
train_df_filtered = train_df[(train_df['NDVI']>0) & (train_df['ETa_corr']>0)]

train_df_filtered = train_df_filtered.rename(columns={'TA': 'Air Temperature', 'RH': 'relative_humidity',
                                                      'SW_IN':'Downward Short-Wave Radiation Flux',
                                                      'LW_IN':'Downward Long-Wave Radiation Flux',
                                                      'WS':'Wind Speed', 'PA':'Air Pressure',
                                                      'P_RAIN':'Total Precipitation'})

# Drop 'Downward Long-Wave Radiation Flux' and 'Total Precipitation' based on HXGB001 results
train_df_filtered = train_df_filtered.drop(columns=['Downward Long-Wave Radiation Flux', 'Total Precipitation', 'Wind Speed', 'Air Pressure'])

# train X and y
X_train_val = train_df_filtered.drop(columns=['ETa_corr', 'ETa_NaN_flag']).round(2)  # Training features
y_train_val = train_df_filtered['ETa_corr'].round(3)  # Training target

# %%
def objective(trial):
    # Choose between two objectives: standard regression or huber loss for robustness.
    objective_choice = trial.suggest_categorical('objective', ['regression', 'huber'])
    
    param = {
        'objective': objective_choice,
        'metric': 'mae',
        'learning_rate': round(trial.suggest_float('learning_rate', 0.001, 0.1, log=True),3),
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'max_depth': trial.suggest_int('max_depth', 3, 25),
        'min_data_in_leaf': 25,
        'feature_fraction': round(trial.suggest_float('feature_fraction', 0.1, 1.0),3),
        'bagging_fraction': round(trial.suggest_float('bagging_fraction', 0.1, 1.0),3),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'lambda_l1': round(trial.suggest_float('lambda_l1', 0.1, 10, log=True),3),
        'lambda_l2': round(trial.suggest_float('lambda_l2', 1e-3, 10.0, log=True),3),
        'feature_pre_filter': False,
        'verbose': -1,
    }

    # add constant params
    #param['feature_contri']= [1.0, 1.0, 1.0, 0.5],
    param['monotone_constraints']        = '1,0,0,0'
    param['monotone_constraints_method'] = 'intermediate'
    
    # Bin target into quantiles for stratification
    y_bins = pd.qcut(y_train_val, q=10, labels=False, duplicates='drop')

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    mae_scores = []
    
    for train_idx, valid_idx in skf.split(X_train_val, y_bins):
        X_train_fold, X_valid_fold = X_train_val.iloc[train_idx], X_train_val.iloc[valid_idx]
        y_train_fold, y_valid_fold = y_train_val.iloc[train_idx], y_train_val.iloc[valid_idx]

        lgb_train = lgb.Dataset(X_train_fold, y_train_fold)
        lgb_valid = lgb.Dataset(X_valid_fold, y_valid_fold, reference=lgb_train)

        gbm = lgb.train(
            param,
            lgb_train,
            num_boost_round=2500,
            valid_sets=[lgb_valid]
        )

        preds = gbm.predict(X_valid_fold, num_iteration=gbm.best_iteration)
        fold_mae = mean_absolute_error(y_valid_fold, preds)
        mae_scores.append(fold_mae)

    return np.mean(mae_scores)

# Create and run the study
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=250)

# Display the best trial results
print("Best trial:")
print("  MAE: ", study.best_trial.value)
print("  Best hyperparameters: ", study.best_trial.params)
# Out:
# [I 2025-10-31 11:49:42,126] A new study created in memory with name: no-name-7cea1bce-a1a4-4f64-92d1-f49d4cf0aa10
# [I 2025-10-31 11:50:00,956] Trial 0 finished with value: 0.0799377394107266 and parameters: {'objective': 'regression', 'learning_rate': 0.001244524732179334, 'num_leaves': 99, 'max_depth': 7, 'feature_fraction': 0.7107229555546062, 'bagging_fraction': 0.3746927859082103, 'bagging_freq': 5, 'lambda_l1': 1.0138669401184173, 'lambda_l2': 0.5710568903274414}. Best is trial 0 with value: 0.0799377394107266.
# [I 2025-10-31 11:50:31,747] Trial 1 finished with value: 0.08088373755925772 and parameters: {'objective': 'regression', 'learning_rate': 0.00150203705292443, 'num_leaves': 134, 'max_depth': 19, 'feature_fraction': 0.5448432755020769, 'bagging_fraction': 0.39582048338412545, 'bagging_freq': 9, 'lambda_l1': 0.19137851903805866, 'lambda_l2': 0.001502166631086976}. Best is trial 0 with value: 0.0799377394107266.
# [I 2025-10-31 11:50:43,676] Trial 2 finished with value: 0.07366814356582498 and parameters: {'objective': 'regression', 'learning_rate': 0.0016535961003724712, 'num_leaves': 21, 'max_depth': 16, 'feature_fraction': 0.9350822920185943, 'bagging_fraction': 0.3570597076318057, 'bagging_freq': 10, 'lambda_l1': 7.882434841032867, 'lambda_l2': 0.004805844787210657}. Best is trial 2 with value: 0.07366814356582498.
# [I 2025-10-31 11:51:02,381] Trial 3 finished with value: 0.07220884413013953 and parameters: {'objective': 'regression', 'learning_rate': 0.01594212131949611, 'num_leaves': 42, 'max_depth': 14, 'feature_fraction': 0.7717272057526438, 'bagging_fraction': 0.4083396330270438, 'bagging_freq': 5, 'lambda_l1': 0.30032033496771726, 'lambda_l2': 1.2127136330600483}. Best is trial 3 with value: 0.07220884413013953.
# [I 2025-10-31 11:51:27,617] Trial 4 finished with value: 0.09797321831150899 and parameters: {'objective': 'regression', 'learning_rate': 0.026249482735451433, 'num_leaves': 116, 'max_depth': 16, 'feature_fraction': 0.2898460116438903, 'bagging_fraction': 0.46986761765883733, 'bagging_freq': 7, 'lambda_l1': 0.23753708615080688, 'lambda_l2': 0.11192593420019514}. Best is trial 3 with value: 0.07220884413013953.
# [I 2025-10-31 11:51:32,140] Trial 5 finished with value: 0.09667829595678239 and parameters: {'objective': 'huber', 'learning_rate': 0.04331039972661128, 'num_leaves': 43, 'max_depth': 25, 'feature_fraction': 0.169678600248182, 'bagging_fraction': 0.30623570264322675, 'bagging_freq': 6, 'lambda_l1': 5.457419769628772, 'lambda_l2': 0.036911941744476214}. Best is trial 3 with value: 0.07220884413013953.
# [I 2025-10-31 11:52:00,819] Trial 6 finished with value: 0.07613275823019904 and parameters: {'objective': 'regression', 'learning_rate': 0.04547041231291579, 'num_leaves': 74, 'max_depth': 25, 'feature_fraction': 0.6277504371930114, 'bagging_fraction': 0.885930362197927, 'bagging_freq': 8, 'lambda_l1': 0.22533265878148528, 'lambda_l2': 0.010805231065710425}. Best is trial 3 with value: 0.07220884413013953.
# [I 2025-10-31 11:52:06,045] Trial 7 finished with value: 0.09657889329746706 and parameters: {'objective': 'huber', 'learning_rate': 0.016635685234578087, 'num_leaves': 120, 'max_depth': 9, 'feature_fraction': 0.33844165700774176, 'bagging_fraction': 0.5050784359978548, 'bagging_freq': 10, 'lambda_l1': 8.004425208126756, 'lambda_l2': 0.06445629251403703}. Best is trial 3 with value: 0.07220884413013953.
# [I 2025-10-31 11:52:22,011] Trial 8 finished with value: 0.09977356657535327 and parameters: {'objective': 'regression', 'learning_rate': 0.0030010808999404474, 'num_leaves': 52, 'max_depth': 25, 'feature_fraction': 0.3363459043748567, 'bagging_fraction': 0.6670911904256538, 'bagging_freq': 8, 'lambda_l1': 0.3839136831370788, 'lambda_l2': 1.0967281297268565}. Best is trial 3 with value: 0.07220884413013953.
# [I 2025-10-31 11:52:29,584] Trial 9 finished with value: 0.09679758696471821 and parameters: {'objective': 'huber', 'learning_rate': 0.022152148136787748, 'num_leaves': 57, 'max_depth': 5, 'feature_fraction': 0.11831997712347454, 'bagging_fraction': 0.7485977642741005, 'bagging_freq': 7, 'lambda_l1': 1.4766534381424437, 'lambda_l2': 0.5966659357460857}. Best is trial 3 with value: 0.07220884413013953.
# [I 2025-10-31 11:52:42,793] Trial 10 finished with value: 0.07065193846706722 and parameters: {'objective': 'huber', 'learning_rate': 0.007236603242214821, 'num_leaves': 26, 'max_depth': 10, 'feature_fraction': 0.996370243148663, 'bagging_fraction': 0.14555654058737577, 'bagging_freq': 2, 'lambda_l1': 0.5826517879650005, 'lambda_l2': 9.85958017215004}. Best is trial 10 with value: 0.07065193846706722.
# [I 2025-10-31 11:52:54,544] Trial 11 finished with value: 0.07091214630803049 and parameters: {'objective': 'huber', 'learning_rate': 0.007143350510738824, 'num_leaves': 20, 'max_depth': 11, 'feature_fraction': 0.9613299609658665, 'bagging_fraction': 0.10204357424777652, 'bagging_freq': 2, 'lambda_l1': 0.5742810816690902, 'lambda_l2': 9.286380833175645}. Best is trial 10 with value: 0.07065193846706722.
# [I 2025-10-31 11:53:07,136] Trial 12 finished with value: 0.07076363448499692 and parameters: {'objective': 'huber', 'learning_rate': 0.005829281239159582, 'num_leaves': 20, 'max_depth': 11, 'feature_fraction': 0.9843267524862275, 'bagging_fraction': 0.10741486286663603, 'bagging_freq': 1, 'lambda_l1': 0.6119439898879614, 'lambda_l2': 8.067799445073117}. Best is trial 10 with value: 0.07065193846706722.
# [I 2025-10-31 11:53:16,807] Trial 13 finished with value: 0.07197801004780321 and parameters: {'objective': 'huber', 'learning_rate': 0.005422395839769786, 'num_leaves': 76, 'max_depth': 12, 'feature_fraction': 0.8312149790169879, 'bagging_fraction': 0.10856093691793506, 'bagging_freq': 1, 'lambda_l1': 2.158259811360649, 'lambda_l2': 8.311887607635018}. Best is trial 10 with value: 0.07065193846706722.
# [I 2025-10-31 11:53:28,532] Trial 14 finished with value: 0.0703465853787505 and parameters: {'objective': 'huber', 'learning_rate': 0.004933986694590364, 'num_leaves': 34, 'max_depth': 5, 'feature_fraction': 0.9861704829439464, 'bagging_fraction': 0.25927588477569863, 'bagging_freq': 3, 'lambda_l1': 0.11560250983669607, 'lambda_l2': 2.87169598028794}. Best is trial 14 with value: 0.0703465853787505.
# [I 2025-10-31 11:53:34,920] Trial 15 finished with value: 0.0725056988011227 and parameters: {'objective': 'huber', 'learning_rate': 0.0031984882362839076, 'num_leaves': 39, 'max_depth': 3, 'feature_fraction': 0.8512798338979958, 'bagging_fraction': 0.22732787129191961, 'bagging_freq': 3, 'lambda_l1': 0.12650326658046732, 'lambda_l2': 2.3424006592484163}. Best is trial 14 with value: 0.0703465853787505.
# [I 2025-10-31 11:53:52,117] Trial 16 finished with value: 0.07760220288256833 and parameters: {'objective': 'huber', 'learning_rate': 0.002908869942908496, 'num_leaves': 92, 'max_depth': 7, 'feature_fraction': 0.511229363391669, 'bagging_fraction': 0.2502089613721989, 'bagging_freq': 3, 'lambda_l1': 0.11806144308867701, 'lambda_l2': 2.750704039276638}. Best is trial 14 with value: 0.0703465853787505.
# [I 2025-10-31 11:54:01,491] Trial 17 finished with value: 0.07148317655684264 and parameters: {'objective': 'huber', 'learning_rate': 0.09173279677121174, 'num_leaves': 63, 'max_depth': 4, 'feature_fraction': 0.8752548357150779, 'bagging_fraction': 0.6298461881307699, 'bagging_freq': 4, 'lambda_l1': 2.646190524797101, 'lambda_l2': 0.2083212560061976}. Best is trial 14 with value: 0.0703465853787505.
# [I 2025-10-31 11:54:16,271] Trial 18 finished with value: 0.07123034370028522 and parameters: {'objective': 'huber', 'learning_rate': 0.011152056796217178, 'num_leaves': 34, 'max_depth': 7, 'feature_fraction': 0.6903619948084541, 'bagging_fraction': 0.20851497321601759, 'bagging_freq': 3, 'lambda_l1': 0.6536302993552959, 'lambda_l2': 3.1422858127080624}. Best is trial 14 with value: 0.0703465853787505.
# [I 2025-10-31 11:54:24,477] Trial 19 finished with value: 0.0768455932075316 and parameters: {'objective': 'huber', 'learning_rate': 0.009110430932987882, 'num_leaves': 150, 'max_depth': 9, 'feature_fraction': 0.4250020968661317, 'bagging_fraction': 0.1937866300812337, 'bagging_freq': 2, 'lambda_l1': 3.621393317190852, 'lambda_l2': 0.3062813908474062}. Best is trial 14 with value: 0.0703465853787505.
# [I 2025-10-31 11:54:55,080] Trial 20 finished with value: 0.07075700869228052 and parameters: {'objective': 'huber', 'learning_rate': 0.004568944339050874, 'num_leaves': 68, 'max_depth': 21, 'feature_fraction': 0.7822428141238692, 'bagging_fraction': 0.8848220575205125, 'bagging_freq': 4, 'lambda_l1': 1.0986839740020096, 'lambda_l2': 3.7769231935214354}. Best is trial 14 with value: 0.0703465853787505.
# [I 2025-10-31 11:55:27,803] Trial 21 finished with value: 0.06989175616997874 and parameters: {'objective': 'huber', 'learning_rate': 0.0043453369557147755, 'num_leaves': 68, 'max_depth': 21, 'feature_fraction': 0.9975906307930876, 'bagging_fraction': 0.9997157750436828, 'bagging_freq': 2, 'lambda_l1': 1.1074238704937054, 'lambda_l2': 3.570386679501527}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:55:49,837] Trial 22 finished with value: 0.07007060084410895 and parameters: {'objective': 'huber', 'learning_rate': 0.003656701424267103, 'num_leaves': 31, 'max_depth': 21, 'feature_fraction': 0.9990611560042532, 'bagging_fraction': 0.7851838456912212, 'bagging_freq': 2, 'lambda_l1': 1.7806890441403072, 'lambda_l2': 1.4016285211195363}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:56:20,069] Trial 23 finished with value: 0.07065906916982094 and parameters: {'objective': 'huber', 'learning_rate': 0.002325895359131298, 'num_leaves': 50, 'max_depth': 21, 'feature_fraction': 0.9076530565116695, 'bagging_fraction': 0.9646398714713313, 'bagging_freq': 1, 'lambda_l1': 2.2249720750967064, 'lambda_l2': 1.1191902667271387}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:56:53,269] Trial 24 finished with value: 0.06995344341732464 and parameters: {'objective': 'huber', 'learning_rate': 0.004118003626776976, 'num_leaves': 81, 'max_depth': 20, 'feature_fraction': 0.9085831432266129, 'bagging_fraction': 0.789605674543623, 'bagging_freq': 4, 'lambda_l1': 1.860256955164629, 'lambda_l2': 0.4214733879120692}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:57:18,907] Trial 25 finished with value: 0.0706860124592011 and parameters: {'objective': 'huber', 'learning_rate': 0.003922097422875259, 'num_leaves': 83, 'max_depth': 22, 'feature_fraction': 0.7984946499887426, 'bagging_fraction': 0.8012890805950933, 'bagging_freq': 4, 'lambda_l1': 1.7363449291382966, 'lambda_l2': 0.3855907946108609}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:57:47,520] Trial 26 finished with value: 0.07109276048870913 and parameters: {'objective': 'huber', 'learning_rate': 0.0022266489420640074, 'num_leaves': 96, 'max_depth': 18, 'feature_fraction': 0.8960527464996823, 'bagging_fraction': 0.998006868310091, 'bagging_freq': 2, 'lambda_l1': 3.512309306655621, 'lambda_l2': 0.15043991369991586}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:58:15,683] Trial 27 finished with value: 0.07147504210332883 and parameters: {'objective': 'huber', 'learning_rate': 0.002001682658842979, 'num_leaves': 79, 'max_depth': 23, 'feature_fraction': 0.7098739097488209, 'bagging_fraction': 0.7800482795472086, 'bagging_freq': 4, 'lambda_l1': 1.1725522494965646, 'lambda_l2': 1.335629748431432}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:58:35,397] Trial 28 finished with value: 0.07014130075917022 and parameters: {'objective': 'huber', 'learning_rate': 0.009213215942722388, 'num_leaves': 89, 'max_depth': 19, 'feature_fraction': 0.9109228793810045, 'bagging_fraction': 0.9108818553590295, 'bagging_freq': 5, 'lambda_l1': 3.510698734966895, 'lambda_l2': 0.032697835733959804}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:59:04,902] Trial 29 finished with value: 0.07066563618101371 and parameters: {'objective': 'huber', 'learning_rate': 0.0031492465339449808, 'num_leaves': 108, 'max_depth': 17, 'feature_fraction': 0.6288969715329217, 'bagging_fraction': 0.6039300288866642, 'bagging_freq': 6, 'lambda_l1': 0.8503385867600852, 'lambda_l2': 0.6950613506919826}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:59:29,651] Trial 30 finished with value: 0.07102239210496761 and parameters: {'objective': 'huber', 'learning_rate': 0.012282673651052204, 'num_leaves': 61, 'max_depth': 23, 'feature_fraction': 0.7539790493464933, 'bagging_fraction': 0.7196719093921907, 'bagging_freq': 2, 'lambda_l1': 1.5958957399583287, 'lambda_l2': 0.3548205229475974}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 11:59:47,617] Trial 31 finished with value: 0.07031525280954862 and parameters: {'objective': 'huber', 'learning_rate': 0.008092324347053316, 'num_leaves': 90, 'max_depth': 20, 'feature_fraction': 0.91707006779603, 'bagging_fraction': 0.8674470275565664, 'bagging_freq': 5, 'lambda_l1': 4.712625080390917, 'lambda_l2': 0.03820313983091809}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:00:11,776] Trial 32 finished with value: 0.08028916096513602 and parameters: {'objective': 'huber', 'learning_rate': 0.0012922915313618387, 'num_leaves': 106, 'max_depth': 19, 'feature_fraction': 0.8636901749533776, 'bagging_fraction': 0.925930413950923, 'bagging_freq': 5, 'lambda_l1': 2.7102697991123526, 'lambda_l2': 0.015795480992330763}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:00:55,093] Trial 33 finished with value: 0.0699923635390745 and parameters: {'objective': 'huber', 'learning_rate': 0.004126893536201445, 'num_leaves': 101, 'max_depth': 19, 'feature_fraction': 0.9466327481179375, 'bagging_fraction': 0.835252126084421, 'bagging_freq': 3, 'lambda_l1': 0.9048063256706861, 'lambda_l2': 0.0016040085349181593}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:01:33,311] Trial 34 finished with value: 0.07460033970000132 and parameters: {'objective': 'regression', 'learning_rate': 0.0010338137144191098, 'num_leaves': 104, 'max_depth': 14, 'feature_fraction': 0.9447064631427143, 'bagging_fraction': 0.8226248672836849, 'bagging_freq': 3, 'lambda_l1': 0.9080935505227596, 'lambda_l2': 0.006441824342033525}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:02:10,813] Trial 35 finished with value: 0.06993059672146969 and parameters: {'objective': 'regression', 'learning_rate': 0.004187650205716914, 'num_leaves': 116, 'max_depth': 16, 'feature_fraction': 0.998943586254259, 'bagging_fraction': 0.7181656948232187, 'bagging_freq': 1, 'lambda_l1': 1.3320003356922117, 'lambda_l2': 0.0013590571243080158}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:02:48,253] Trial 36 finished with value: 0.071148519210867 and parameters: {'objective': 'regression', 'learning_rate': 0.0015672870229556494, 'num_leaves': 130, 'max_depth': 16, 'feature_fraction': 0.8080524454671517, 'bagging_fraction': 0.7008767692652033, 'bagging_freq': 1, 'lambda_l1': 0.42202859271942383, 'lambda_l2': 0.0013388205325869313}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:03:31,681] Trial 37 finished with value: 0.0704798081163348 and parameters: {'objective': 'regression', 'learning_rate': 0.006190062740853298, 'num_leaves': 115, 'max_depth': 15, 'feature_fraction': 0.940268405187064, 'bagging_fraction': 0.8505246010548649, 'bagging_freq': 4, 'lambda_l1': 0.776581768069377, 'lambda_l2': 0.0045651857582576635}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:03:59,284] Trial 38 finished with value: 0.07068544657508846 and parameters: {'objective': 'regression', 'learning_rate': 0.004215203580267905, 'num_leaves': 129, 'max_depth': 18, 'feature_fraction': 0.6500075221374801, 'bagging_fraction': 0.5527847222490418, 'bagging_freq': 1, 'lambda_l1': 1.2722946022230546, 'lambda_l2': 0.002563909052579326}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:04:33,780] Trial 39 finished with value: 0.07140204389295687 and parameters: {'objective': 'regression', 'learning_rate': 0.0024517588372662924, 'num_leaves': 144, 'max_depth': 23, 'feature_fraction': 0.7466574823764782, 'bagging_fraction': 0.9572068361222582, 'bagging_freq': 3, 'lambda_l1': 1.0363077227638406, 'lambda_l2': 0.0011238225848479782}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:05:08,929] Trial 40 finished with value: 0.07112150751819854 and parameters: {'objective': 'regression', 'learning_rate': 0.0017186062567705058, 'num_leaves': 99, 'max_depth': 13, 'feature_fraction': 0.8411013415879117, 'bagging_fraction': 0.6608624249595517, 'bagging_freq': 2, 'lambda_l1': 0.38896556902149354, 'lambda_l2': 0.013553763377148921}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:05:42,121] Trial 41 finished with value: 0.06993370718331186 and parameters: {'objective': 'regression', 'learning_rate': 0.0037385238379563815, 'num_leaves': 123, 'max_depth': 20, 'feature_fraction': 0.9908947279367054, 'bagging_fraction': 0.7586950063885239, 'bagging_freq': 2, 'lambda_l1': 1.8190183366231496, 'lambda_l2': 0.002090786934458511}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:06:19,385] Trial 42 finished with value: 0.06992019339413093 and parameters: {'objective': 'regression', 'learning_rate': 0.00407953751175835, 'num_leaves': 119, 'max_depth': 17, 'feature_fraction': 0.9479302651322661, 'bagging_fraction': 0.7570153307167982, 'bagging_freq': 1, 'lambda_l1': 1.293928425798219, 'lambda_l2': 0.002592956790889827}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:06:59,855] Trial 43 finished with value: 0.07012296714768847 and parameters: {'objective': 'regression', 'learning_rate': 0.00615080447552681, 'num_leaves': 122, 'max_depth': 17, 'feature_fraction': 0.8861220249056199, 'bagging_fraction': 0.7299869168240891, 'bagging_freq': 1, 'lambda_l1': 1.3670119074137728, 'lambda_l2': 0.002847377284837831}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:07:22,615] Trial 44 finished with value: 0.07028164264653573 and parameters: {'objective': 'regression', 'learning_rate': 0.002616925043562474, 'num_leaves': 138, 'max_depth': 15, 'feature_fraction': 0.9430380108776614, 'bagging_fraction': 0.4499349325766771, 'bagging_freq': 1, 'lambda_l1': 1.9882997586673676, 'lambda_l2': 0.002777735378617979}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:07:43,333] Trial 45 finished with value: 0.07025242822183986 and parameters: {'objective': 'regression', 'learning_rate': 0.0150438310253923, 'num_leaves': 113, 'max_depth': 20, 'feature_fraction': 0.9976801013325644, 'bagging_fraction': 0.6852287381990916, 'bagging_freq': 2, 'lambda_l1': 2.667820505676734, 'lambda_l2': 0.0050719842265398605}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:08:16,163] Trial 46 finished with value: 0.06998189820458366 and parameters: {'objective': 'regression', 'learning_rate': 0.003478740450503984, 'num_leaves': 125, 'max_depth': 17, 'feature_fraction': 0.9674778092443674, 'bagging_fraction': 0.5676272090116639, 'bagging_freq': 1, 'lambda_l1': 1.4380196024080165, 'lambda_l2': 0.002028088129807615}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:08:41,154] Trial 47 finished with value: 0.07652443192279479 and parameters: {'objective': 'regression', 'learning_rate': 0.004832569528335094, 'num_leaves': 71, 'max_depth': 24, 'feature_fraction': 0.5556469765157079, 'bagging_fraction': 0.7520999813458465, 'bagging_freq': 9, 'lambda_l1': 0.7153031691100574, 'lambda_l2': 0.02210638098460254}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:09:20,829] Trial 48 finished with value: 0.0716927361679141 and parameters: {'objective': 'regression', 'learning_rate': 0.006809822651162368, 'num_leaves': 137, 'max_depth': 20, 'feature_fraction': 0.8213455666899772, 'bagging_fraction': 0.5014722731516814, 'bagging_freq': 2, 'lambda_l1': 0.49952396066525007, 'lambda_l2': 0.0624780017653516}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:09:27,160] Trial 49 finished with value: 0.09734806243723933 and parameters: {'objective': 'regression', 'learning_rate': 0.005389907966969773, 'num_leaves': 85, 'max_depth': 18, 'feature_fraction': 0.26644947600518964, 'bagging_fraction': 0.6043573444843836, 'bagging_freq': 1, 'lambda_l1': 9.645157091769399, 'lambda_l2': 5.011974872305337}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:09:49,253] Trial 50 finished with value: 0.0717975585216427 and parameters: {'objective': 'regression', 'learning_rate': 0.0019503294685460164, 'num_leaves': 111, 'max_depth': 22, 'feature_fraction': 0.9664483083483576, 'bagging_fraction': 0.7676760494974799, 'bagging_freq': 6, 'lambda_l1': 5.589895194354684, 'lambda_l2': 0.010267935793865608}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:10:19,760] Trial 51 finished with value: 0.06996492642926654 and parameters: {'objective': 'regression', 'learning_rate': 0.0032960310485700946, 'num_leaves': 123, 'max_depth': 17, 'feature_fraction': 0.9599040466035665, 'bagging_fraction': 0.5585184891924337, 'bagging_freq': 1, 'lambda_l1': 1.4269429056863199, 'lambda_l2': 0.0020372131569629855}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:10:46,046] Trial 52 finished with value: 0.07013653551196393 and parameters: {'objective': 'regression', 'learning_rate': 0.0029007068633125858, 'num_leaves': 120, 'max_depth': 14, 'feature_fraction': 0.8805263184526717, 'bagging_fraction': 0.6577114232656799, 'bagging_freq': 1, 'lambda_l1': 2.14226602147255, 'lambda_l2': 0.001028228348742253}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:11:23,378] Trial 53 finished with value: 0.06997206048018753 and parameters: {'objective': 'regression', 'learning_rate': 0.0035833873831218415, 'num_leaves': 128, 'max_depth': 15, 'feature_fraction': 0.9165096102723237, 'bagging_fraction': 0.6322398685510576, 'bagging_freq': 2, 'lambda_l1': 1.2566561128737241, 'lambda_l2': 0.0076361266332832314}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:11:50,134] Trial 54 finished with value: 0.07008821055755544 and parameters: {'objective': 'regression', 'learning_rate': 0.004758851232583736, 'num_leaves': 119, 'max_depth': 16, 'feature_fraction': 0.9671721909619612, 'bagging_fraction': 0.4236141273825482, 'bagging_freq': 1, 'lambda_l1': 1.6304036612847654, 'lambda_l2': 0.004125871072833267}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:12:10,871] Trial 55 finished with value: 0.07092124514807144 and parameters: {'objective': 'regression', 'learning_rate': 0.002801942246306254, 'num_leaves': 80, 'max_depth': 18, 'feature_fraction': 0.8563581889303726, 'bagging_fraction': 0.30789462400405165, 'bagging_freq': 2, 'lambda_l1': 1.076027252245585, 'lambda_l2': 0.0016522578840736742}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:12:32,580] Trial 56 finished with value: 0.07016717728769337 and parameters: {'objective': 'regression', 'learning_rate': 0.007816661634974414, 'num_leaves': 67, 'max_depth': 20, 'feature_fraction': 0.9277726522159715, 'bagging_fraction': 0.4953260351147252, 'bagging_freq': 3, 'lambda_l1': 2.4424612681728393, 'lambda_l2': 0.0031592956013720506}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:12:59,592] Trial 57 finished with value: 0.07087457090838838 and parameters: {'objective': 'regression', 'learning_rate': 0.026629276738237742, 'num_leaves': 136, 'max_depth': 22, 'feature_fraction': 0.9990916963508638, 'bagging_fraction': 0.8053545343410085, 'bagging_freq': 7, 'lambda_l1': 1.8910114000546085, 'lambda_l2': 0.0017495825690747448}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:13:16,813] Trial 58 finished with value: 0.07039304981292185 and parameters: {'objective': 'regression', 'learning_rate': 0.005590657499099955, 'num_leaves': 142, 'max_depth': 17, 'feature_fraction': 0.9683445889857418, 'bagging_fraction': 0.3660706452537199, 'bagging_freq': 1, 'lambda_l1': 2.981567119033645, 'lambda_l2': 0.0021580808839703866}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:13:42,705] Trial 59 finished with value: 0.06994085420281473 and parameters: {'objective': 'regression', 'learning_rate': 0.0037317136854529394, 'num_leaves': 53, 'max_depth': 19, 'feature_fraction': 0.8910280342999931, 'bagging_fraction': 0.7190535812843016, 'bagging_freq': 2, 'lambda_l1': 1.530123344942031, 'lambda_l2': 0.09126904137081884}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:14:09,773] Trial 60 finished with value: 0.06996043023264645 and parameters: {'objective': 'regression', 'learning_rate': 0.004036148889164113, 'num_leaves': 57, 'max_depth': 21, 'feature_fraction': 0.8886749384956671, 'bagging_fraction': 0.7221713517769288, 'bagging_freq': 3, 'lambda_l1': 1.7527187004628773, 'lambda_l2': 0.07415269131348784}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:14:34,174] Trial 61 finished with value: 0.06996366309279708 and parameters: {'objective': 'regression', 'learning_rate': 0.0040294988931774195, 'num_leaves': 48, 'max_depth': 21, 'feature_fraction': 0.8910981129636341, 'bagging_fraction': 0.7148683469585688, 'bagging_freq': 3, 'lambda_l1': 1.5768110781234999, 'lambda_l2': 0.10480524402978415}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:14:58,460] Trial 62 finished with value: 0.07070891535039478 and parameters: {'objective': 'regression', 'learning_rate': 0.004633634017128296, 'num_leaves': 55, 'max_depth': 19, 'feature_fraction': 0.8443260450302464, 'bagging_fraction': 0.7464719066725487, 'bagging_freq': 2, 'lambda_l1': 1.1746399911824572, 'lambda_l2': 0.06835345401376708}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:15:21,358] Trial 63 finished with value: 0.07009996648280159 and parameters: {'objective': 'regression', 'learning_rate': 0.006701825158249549, 'num_leaves': 42, 'max_depth': 24, 'feature_fraction': 0.9168756287569383, 'bagging_fraction': 0.6917582696106449, 'bagging_freq': 4, 'lambda_l1': 1.8823410020203082, 'lambda_l2': 1.9667099333927065}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:15:36,370] Trial 64 finished with value: 0.076835779304195 and parameters: {'objective': 'regression', 'learning_rate': 0.0037123293875676233, 'num_leaves': 60, 'max_depth': 21, 'feature_fraction': 0.44627084829635716, 'bagging_fraction': 0.8118488602242717, 'bagging_freq': 2, 'lambda_l1': 3.0996883630995917, 'lambda_l2': 0.18973235126619525}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:16:00,148] Trial 65 finished with value: 0.07185578776704843 and parameters: {'objective': 'regression', 'learning_rate': 0.002024996359307479, 'num_leaves': 66, 'max_depth': 22, 'feature_fraction': 0.8693825723285783, 'bagging_fraction': 0.9089819546538458, 'bagging_freq': 3, 'lambda_l1': 2.263638602524616, 'lambda_l2': 0.6573744482790828}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:16:29,848] Trial 66 finished with value: 0.070681173464922 and parameters: {'objective': 'regression', 'learning_rate': 0.002643325206676028, 'num_leaves': 75, 'max_depth': 20, 'feature_fraction': 0.7694963758255082, 'bagging_fraction': 0.7786449632628458, 'bagging_freq': 3, 'lambda_l1': 1.0309203742944493, 'lambda_l2': 0.14533741387758617}. Best is trial 21 with value: 0.06989175616997874.
# [I 2025-10-31 12:16:59,549] Trial 67 finished with value: 0.06988564676936093 and parameters: {'objective': 'huber', 'learning_rate': 0.0031660825551459958, 'num_leaves': 53, 'max_depth': 19, 'feature_fraction': 0.8986310054257073, 'bagging_fraction': 0.8686537053607065, 'bagging_freq': 2, 'lambda_l1': 0.8422279306476387, 'lambda_l2': 0.07334332871494746}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:17:24,425] Trial 68 finished with value: 0.07002777329983113 and parameters: {'objective': 'huber', 'learning_rate': 0.0053621961084805245, 'num_leaves': 48, 'max_depth': 19, 'feature_fraction': 0.9295796121325786, 'bagging_fraction': 0.881381946305714, 'bagging_freq': 2, 'lambda_l1': 0.3025238426055849, 'lambda_l2': 0.04205127059144683}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:17:55,603] Trial 69 finished with value: 0.07066445237450708 and parameters: {'objective': 'huber', 'learning_rate': 0.0031563117404444395, 'num_leaves': 94, 'max_depth': 18, 'feature_fraction': 0.796782730341206, 'bagging_fraction': 0.84869170972559, 'bagging_freq': 2, 'lambda_l1': 0.8106042295579319, 'lambda_l2': 0.026558426239016893}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:18:32,266] Trial 70 finished with value: 0.07005114215456966 and parameters: {'objective': 'huber', 'learning_rate': 0.0022972618142856776, 'num_leaves': 72, 'max_depth': 19, 'feature_fraction': 0.9869716831690887, 'bagging_fraction': 0.9609366903956464, 'bagging_freq': 1, 'lambda_l1': 0.5590750158916975, 'lambda_l2': 0.27437630514752864}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:18:58,381] Trial 71 finished with value: 0.06993628822276557 and parameters: {'objective': 'huber', 'learning_rate': 0.004262004432369785, 'num_leaves': 53, 'max_depth': 20, 'feature_fraction': 0.8940395015560725, 'bagging_fraction': 0.7395516092832833, 'bagging_freq': 2, 'lambda_l1': 0.908679165422265, 'lambda_l2': 0.07635974570650118}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:19:22,163] Trial 72 finished with value: 0.07064659832535695 and parameters: {'objective': 'huber', 'learning_rate': 0.004217120822609779, 'num_leaves': 53, 'max_depth': 16, 'feature_fraction': 0.8331940873467427, 'bagging_fraction': 0.7555848358295371, 'bagging_freq': 2, 'lambda_l1': 0.9341072433789152, 'lambda_l2': 0.1379649321419562}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:19:38,695] Trial 73 finished with value: 0.07302676499350778 and parameters: {'objective': 'huber', 'learning_rate': 0.08990730192339304, 'num_leaves': 45, 'max_depth': 20, 'feature_fraction': 0.9470372187413068, 'bagging_fraction': 0.9956428504390554, 'bagging_freq': 2, 'lambda_l1': 0.7390410708983721, 'lambda_l2': 0.8707554809804744}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:20:01,134] Trial 74 finished with value: 0.07002655772830987 and parameters: {'objective': 'huber', 'learning_rate': 0.0033526121606836227, 'num_leaves': 35, 'max_depth': 18, 'feature_fraction': 0.9121304322095044, 'bagging_fraction': 0.9358887041091778, 'bagging_freq': 1, 'lambda_l1': 0.6476774676256267, 'lambda_l2': 0.04838658115912185}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:20:30,288] Trial 75 finished with value: 0.07003283951934462 and parameters: {'objective': 'huber', 'learning_rate': 0.005300340417901615, 'num_leaves': 60, 'max_depth': 22, 'feature_fraction': 0.9737955391457225, 'bagging_fraction': 0.8321243406793847, 'bagging_freq': 8, 'lambda_l1': 1.3092363410458774, 'lambda_l2': 0.43868132196142384}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:21:01,236] Trial 76 finished with value: 0.07038770925030229 and parameters: {'objective': 'huber', 'learning_rate': 0.008481005425215472, 'num_leaves': 64, 'max_depth': 20, 'feature_fraction': 0.8997907536687292, 'bagging_fraction': 0.7959750363194249, 'bagging_freq': 4, 'lambda_l1': 1.117017257801977, 'lambda_l2': 6.574598746761356}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:21:39,399] Trial 77 finished with value: 0.07013033138429094 and parameters: {'objective': 'huber', 'learning_rate': 0.0017558275430051451, 'num_leaves': 88, 'max_depth': 19, 'feature_fraction': 0.9368619459030709, 'bagging_fraction': 0.6694998159707694, 'bagging_freq': 1, 'lambda_l1': 0.9587232912028057, 'lambda_l2': 0.05302410126867568}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:21:54,735] Trial 78 finished with value: 0.07077789027449635 and parameters: {'objective': 'huber', 'learning_rate': 0.004489954210188967, 'num_leaves': 24, 'max_depth': 21, 'feature_fraction': 0.736359037023102, 'bagging_fraction': 0.8675636750850176, 'bagging_freq': 2, 'lambda_l1': 1.5836700628176215, 'lambda_l2': 0.0801628842534972}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:22:15,384] Trial 79 finished with value: 0.070730412762702 and parameters: {'objective': 'huber', 'learning_rate': 0.0062565351304338735, 'num_leaves': 39, 'max_depth': 13, 'feature_fraction': 0.8631705295357677, 'bagging_fraction': 0.9073944237214522, 'bagging_freq': 2, 'lambda_l1': 1.2969065990460746, 'lambda_l2': 0.2245041478417267}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:22:45,951] Trial 80 finished with value: 0.06991902634124222 and parameters: {'objective': 'huber', 'learning_rate': 0.0029514520190426605, 'num_leaves': 70, 'max_depth': 17, 'feature_fraction': 0.996004736351374, 'bagging_fraction': 0.6325828134416027, 'bagging_freq': 3, 'lambda_l1': 0.8433370252597359, 'lambda_l2': 1.7918663426149941}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:23:18,501] Trial 81 finished with value: 0.06990918679008876 and parameters: {'objective': 'huber', 'learning_rate': 0.0025188408899874735, 'num_leaves': 78, 'max_depth': 17, 'feature_fraction': 0.9988847304838933, 'bagging_fraction': 0.6174900953553076, 'bagging_freq': 3, 'lambda_l1': 0.829154075967195, 'lambda_l2': 3.359074595328868}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:23:51,803] Trial 82 finished with value: 0.07013225036908212 and parameters: {'objective': 'huber', 'learning_rate': 0.0024714402978179063, 'num_leaves': 70, 'max_depth': 16, 'feature_fraction': 0.9855970981705929, 'bagging_fraction': 0.6343064629413103, 'bagging_freq': 3, 'lambda_l1': 0.6903843709516337, 'lambda_l2': 3.4005260419861876}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:24:22,468] Trial 83 finished with value: 0.06991970338224922 and parameters: {'objective': 'huber', 'learning_rate': 0.003011509476636069, 'num_leaves': 62, 'max_depth': 15, 'feature_fraction': 0.9522238701283481, 'bagging_fraction': 0.6124805984805831, 'bagging_freq': 2, 'lambda_l1': 0.8360187986186897, 'lambda_l2': 1.7963820525517824}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:24:54,978] Trial 84 finished with value: 0.06991772857685433 and parameters: {'objective': 'huber', 'learning_rate': 0.0030712227561541343, 'num_leaves': 77, 'max_depth': 15, 'feature_fraction': 0.9536609545686902, 'bagging_fraction': 0.6001042852119851, 'bagging_freq': 3, 'lambda_l1': 0.5247287043513734, 'lambda_l2': 1.7107985958083611}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:25:28,349] Trial 85 finished with value: 0.0700421437394831 and parameters: {'objective': 'huber', 'learning_rate': 0.0021443086563209942, 'num_leaves': 76, 'max_depth': 15, 'feature_fraction': 0.9986268393684926, 'bagging_fraction': 0.5895583763401188, 'bagging_freq': 3, 'lambda_l1': 0.5171987298406563, 'lambda_l2': 1.7370282660203695}. Best is trial 67 with value: 0.06988564676936093.
# [I 2025-10-31 12:26:00,223] Trial 86 finished with value: 0.06987170696529948 and parameters: {'objective': 'huber', 'learning_rate': 0.0031124332853415433, 'num_leaves': 73, 'max_depth': 15, 'feature_fraction': 0.9540064443030437, 'bagging_fraction': 0.5804067290177805, 'bagging_freq': 3, 'lambda_l1': 0.1700777350010077, 'lambda_l2': 4.639949469454029}. Best is trial 86 with value: 0.06987170696529948.
# [I 2025-10-31 12:26:33,991] Trial 87 finished with value: 0.06988350405594 and parameters: {'objective': 'huber', 'learning_rate': 0.0029273239353843766, 'num_leaves': 78, 'max_depth': 13, 'feature_fraction': 0.9666362918558327, 'bagging_fraction': 0.5331389732676292, 'bagging_freq': 4, 'lambda_l1': 0.2179871083125213, 'lambda_l2': 4.578582922958642}. Best is trial 86 with value: 0.06987170696529948.
# [I 2025-10-31 12:27:10,878] Trial 88 finished with value: 0.07413849693755215 and parameters: {'objective': 'huber', 'learning_rate': 0.0014377588799306532, 'num_leaves': 78, 'max_depth': 13, 'feature_fraction': 0.956024943775263, 'bagging_fraction': 0.581705221801508, 'bagging_freq': 5, 'lambda_l1': 0.13943656307090474, 'lambda_l2': 4.486326489721056}. Best is trial 86 with value: 0.06987170696529948.
# [I 2025-10-31 12:27:44,266] Trial 89 finished with value: 0.06988688341079441 and parameters: {'objective': 'huber', 'learning_rate': 0.0029172703450106464, 'num_leaves': 85, 'max_depth': 14, 'feature_fraction': 0.9500701002600405, 'bagging_fraction': 0.5450344345969018, 'bagging_freq': 4, 'lambda_l1': 0.20645010737984731, 'lambda_l2': 2.478851859986654}. Best is trial 86 with value: 0.06987170696529948.
# [I 2025-10-31 12:28:19,354] Trial 90 finished with value: 0.06994735980649436 and parameters: {'objective': 'huber', 'learning_rate': 0.0018096155136574624, 'num_leaves': 83, 'max_depth': 12, 'feature_fraction': 0.9281290416303856, 'bagging_fraction': 0.46808051872344925, 'bagging_freq': 4, 'lambda_l1': 0.2549671978408357, 'lambda_l2': 2.546157146091027}. Best is trial 86 with value: 0.06987170696529948.
# [I 2025-10-31 12:28:50,096] Trial 91 finished with value: 0.06993126388104942 and parameters: {'objective': 'huber', 'learning_rate': 0.0027377057445349593, 'num_leaves': 73, 'max_depth': 14, 'feature_fraction': 0.9553173858372023, 'bagging_fraction': 0.5175302149939072, 'bagging_freq': 4, 'lambda_l1': 0.16871347061952546, 'lambda_l2': 6.270202621515154}. Best is trial 86 with value: 0.06987170696529948.
# [I 2025-10-31 12:29:21,546] Trial 92 finished with value: 0.06988467426884257 and parameters: {'objective': 'huber', 'learning_rate': 0.0030467853917120814, 'num_leaves': 69, 'max_depth': 12, 'feature_fraction': 0.9704479241374061, 'bagging_fraction': 0.5349419682978609, 'bagging_freq': 3, 'lambda_l1': 0.10100042047678043, 'lambda_l2': 1.6818882849131613}. Best is trial 86 with value: 0.06987170696529948.
# [I 2025-10-31 12:29:56,748] Trial 93 finished with value: 0.06985603726642191 and parameters: {'objective': 'huber', 'learning_rate': 0.0028632126230535055, 'num_leaves': 85, 'max_depth': 11, 'feature_fraction': 0.9784895065369983, 'bagging_fraction': 0.5291467554021206, 'bagging_freq': 4, 'lambda_l1': 0.10362003332886573, 'lambda_l2': 1.6296168342712616}. Best is trial 93 with value: 0.06985603726642191.
# [I 2025-10-31 12:30:33,310] Trial 94 finished with value: 0.06990446430876937 and parameters: {'objective': 'huber', 'learning_rate': 0.0023980382053986195, 'num_leaves': 86, 'max_depth': 10, 'feature_fraction': 0.9757849842265305, 'bagging_fraction': 0.53410453754856, 'bagging_freq': 4, 'lambda_l1': 0.10182133262282364, 'lambda_l2': 4.254532653952456}. Best is trial 93 with value: 0.06985603726642191.
# [I 2025-10-31 12:31:06,717] Trial 95 finished with value: 0.06978960712418708 and parameters: {'objective': 'huber', 'learning_rate': 0.0025224808179850726, 'num_leaves': 87, 'max_depth': 9, 'feature_fraction': 0.981685726693808, 'bagging_fraction': 0.5292225072087617, 'bagging_freq': 4, 'lambda_l1': 0.10634504012549198, 'lambda_l2': 4.115823159222463}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:31:42,956] Trial 96 finished with value: 0.06991425865724385 and parameters: {'objective': 'huber', 'learning_rate': 0.0024571278587244834, 'num_leaves': 87, 'max_depth': 11, 'feature_fraction': 0.9751920873661559, 'bagging_fraction': 0.533206905132172, 'bagging_freq': 4, 'lambda_l1': 0.10185917173462312, 'lambda_l2': 4.1881726030746815}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:31:57,142] Trial 97 finished with value: 0.1253372824623323 and parameters: {'objective': 'huber', 'learning_rate': 0.0014274514778996178, 'num_leaves': 83, 'max_depth': 8, 'feature_fraction': 0.19839831680306397, 'bagging_fraction': 0.5358993836107071, 'bagging_freq': 5, 'lambda_l1': 0.14978110183987936, 'lambda_l2': 5.236167528738784}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:32:27,662] Trial 98 finished with value: 0.07005855456602464 and parameters: {'objective': 'huber', 'learning_rate': 0.0021304804861442717, 'num_leaves': 92, 'max_depth': 10, 'feature_fraction': 0.9744561623376574, 'bagging_fraction': 0.4017253509325643, 'bagging_freq': 4, 'lambda_l1': 0.19945553114041656, 'lambda_l2': 8.326329966347812}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:33:03,839] Trial 99 finished with value: 0.0698823826366444 and parameters: {'objective': 'huber', 'learning_rate': 0.001964570652045136, 'num_leaves': 97, 'max_depth': 10, 'feature_fraction': 0.9269932841272277, 'bagging_fraction': 0.44454006092136383, 'bagging_freq': 4, 'lambda_l1': 0.10066023511522651, 'lambda_l2': 2.922946469250781}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:33:31,297] Trial 100 finished with value: 0.09640889431792726 and parameters: {'objective': 'huber', 'learning_rate': 0.0012415767250460574, 'num_leaves': 97, 'max_depth': 10, 'feature_fraction': 0.5566934319970025, 'bagging_fraction': 0.47629489708451905, 'bagging_freq': 5, 'lambda_l1': 0.10169416596317399, 'lambda_l2': 2.185167443999173}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:34:05,918] Trial 101 finished with value: 0.06991790187167238 and parameters: {'objective': 'huber', 'learning_rate': 0.0019008334287956817, 'num_leaves': 85, 'max_depth': 12, 'feature_fraction': 0.924123050060739, 'bagging_fraction': 0.4429372395335998, 'bagging_freq': 4, 'lambda_l1': 0.11750511837474259, 'lambda_l2': 2.9715720397493026}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:34:39,007] Trial 102 finished with value: 0.06992045201200463 and parameters: {'objective': 'huber', 'learning_rate': 0.0016235472134798095, 'num_leaves': 81, 'max_depth': 11, 'feature_fraction': 0.9791677942074026, 'bagging_fraction': 0.5242291851102088, 'bagging_freq': 4, 'lambda_l1': 0.1357842193132783, 'lambda_l2': 3.437949775498426}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:35:13,123] Trial 103 finished with value: 0.06993408050257896 and parameters: {'objective': 'huber', 'learning_rate': 0.002268901877708435, 'num_leaves': 91, 'max_depth': 9, 'feature_fraction': 0.9355590783345226, 'bagging_fraction': 0.5710968027669486, 'bagging_freq': 4, 'lambda_l1': 0.15806754688091476, 'lambda_l2': 6.6363834254499485}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:35:44,276] Trial 104 finished with value: 0.06997401220822054 and parameters: {'objective': 'huber', 'learning_rate': 0.002475497384330204, 'num_leaves': 100, 'max_depth': 9, 'feature_fraction': 0.9133695294969726, 'bagging_fraction': 0.3333454388371925, 'bagging_freq': 5, 'lambda_l1': 0.11058347798125162, 'lambda_l2': 1.027544844775122}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:36:17,461] Trial 105 finished with value: 0.06983826013771563 and parameters: {'objective': 'huber', 'learning_rate': 0.003439632185383547, 'num_leaves': 95, 'max_depth': 10, 'feature_fraction': 0.9759092362967845, 'bagging_fraction': 0.4916824744792606, 'bagging_freq': 4, 'lambda_l1': 0.12940619799320063, 'lambda_l2': 1.4725934294517917}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:36:50,512] Trial 106 finished with value: 0.06981953841559527 and parameters: {'objective': 'huber', 'learning_rate': 0.0028574977650309115, 'num_leaves': 95, 'max_depth': 10, 'feature_fraction': 0.969423878854799, 'bagging_fraction': 0.49791245768115455, 'bagging_freq': 4, 'lambda_l1': 0.18800264016921084, 'lambda_l2': 1.4708949007146368}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:37:17,637] Trial 107 finished with value: 0.07062685367696256 and parameters: {'objective': 'huber', 'learning_rate': 0.003402557353486995, 'num_leaves': 104, 'max_depth': 8, 'feature_fraction': 0.8725142335824211, 'bagging_fraction': 0.49973525544932895, 'bagging_freq': 5, 'lambda_l1': 0.182004773678183, 'lambda_l2': 1.2188992252203057}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:37:53,157] Trial 108 finished with value: 0.0699025112392336 and parameters: {'objective': 'huber', 'learning_rate': 0.0027567578186619003, 'num_leaves': 95, 'max_depth': 11, 'feature_fraction': 0.930574537662636, 'bagging_fraction': 0.48002793481615236, 'bagging_freq': 4, 'lambda_l1': 0.21555459466343774, 'lambda_l2': 1.460728796653431}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:38:27,620] Trial 109 finished with value: 0.06993837131986187 and parameters: {'objective': 'huber', 'learning_rate': 0.0033684792976440238, 'num_leaves': 103, 'max_depth': 12, 'feature_fraction': 0.9048553287156615, 'bagging_fraction': 0.44580092097828283, 'bagging_freq': 5, 'lambda_l1': 0.12609960819910554, 'lambda_l2': 2.548604927113394}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:38:59,570] Trial 110 finished with value: 0.06995197513550458 and parameters: {'objective': 'huber', 'learning_rate': 0.0020037076858698513, 'num_leaves': 98, 'max_depth': 9, 'feature_fraction': 0.9661649581676633, 'bagging_fraction': 0.4314475677781151, 'bagging_freq': 4, 'lambda_l1': 0.260050405682693, 'lambda_l2': 0.8879319868497574}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:39:31,134] Trial 111 finished with value: 0.0700096911857242 and parameters: {'objective': 'huber', 'learning_rate': 0.00273037493880644, 'num_leaves': 96, 'max_depth': 11, 'feature_fraction': 0.9413301302230305, 'bagging_fraction': 0.382254098010821, 'bagging_freq': 4, 'lambda_l1': 0.20927892606771764, 'lambda_l2': 1.4052141491569214}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:40:06,431] Trial 112 finished with value: 0.06984380104850094 and parameters: {'objective': 'huber', 'learning_rate': 0.002894626062427175, 'num_leaves': 94, 'max_depth': 10, 'feature_fraction': 0.926173711169906, 'bagging_fraction': 0.4770062780280168, 'bagging_freq': 4, 'lambda_l1': 0.29771734788590687, 'lambda_l2': 2.1805432927835304}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:40:36,511] Trial 113 finished with value: 0.06980321702816174 and parameters: {'objective': 'huber', 'learning_rate': 0.0030126468355774565, 'num_leaves': 90, 'max_depth': 8, 'feature_fraction': 0.9610895113451766, 'bagging_fraction': 0.5507884601502644, 'bagging_freq': 4, 'lambda_l1': 0.184310138481619, 'lambda_l2': 2.1459573321712995}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:41:03,629] Trial 114 finished with value: 0.06982461598498566 and parameters: {'objective': 'huber', 'learning_rate': 0.0030434543628085264, 'num_leaves': 93, 'max_depth': 8, 'feature_fraction': 0.9583321265257189, 'bagging_fraction': 0.46554543298749596, 'bagging_freq': 4, 'lambda_l1': 0.18360090240585958, 'lambda_l2': 2.3825945615848543}. Best is trial 95 with value: 0.06978960712418708.
# [I 2025-10-31 12:41:29,932] Trial 115 finished with value: 0.06993914375178045 and parameters: {'objective': 'huber', 'learning_rate': 0.003673545152672005, 'num_leaves': 92, 'max_depth': 8, 'feature_fraction': 0.9089818425532648, 'bagging_fraction': 0.4662774294069685, 'bagging_freq': 5, 'lambda_l1': 0.17579698644472738, 'lambda_l2': 5.272887964959982}. Best is trial 95 with value: 0.06978960712418708.
# ...
# [I 2025-10-31 13:28:09,114] Trial 212 finished with value: 0.06994697743606022 and parameters: {'objective': 'huber', 'learning_rate': 0.0022826726568349063, 'num_leaves': 86, 'max_depth': 9, 'feature_fraction': 0.9669256387879723, 'bagging_fraction': 0.5196610100510937, 'bagging_freq': 3, 'lambda_l1': 0.16797534303317205, 'lambda_l2': 6.6245296341302735}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:28:41,406] Trial 213 finished with value: 0.06985100754347644 and parameters: {'objective': 'huber', 'learning_rate': 0.0028843446222812964, 'num_leaves': 89, 'max_depth': 10, 'feature_fraction': 0.9464952434071411, 'bagging_fraction': 0.5474476456567631, 'bagging_freq': 7, 'lambda_l1': 0.18601490395718545, 'lambda_l2': 5.803385603044658}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:28:56,938] Trial 214 finished with value: 0.09988444013840768 and parameters: {'objective': 'huber', 'learning_rate': 0.003110695997913445, 'num_leaves': 84, 'max_depth': 9, 'feature_fraction': 0.29695330483420845, 'bagging_fraction': 0.4790415301058864, 'bagging_freq': 3, 'lambda_l1': 0.14928744155733695, 'lambda_l2': 8.13003623660359}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:29:25,036] Trial 215 finished with value: 0.06979542211301791 and parameters: {'objective': 'huber', 'learning_rate': 0.002658607036090989, 'num_leaves': 90, 'max_depth': 8, 'feature_fraction': 0.9817863804995981, 'bagging_fraction': 0.5094077339197111, 'bagging_freq': 3, 'lambda_l1': 0.18031055897539738, 'lambda_l2': 4.587762597368561}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:29:52,162] Trial 216 finished with value: 0.0700829753330308 and parameters: {'objective': 'huber', 'learning_rate': 0.002419216458890396, 'num_leaves': 92, 'max_depth': 7, 'feature_fraction': 0.9990467719400778, 'bagging_fraction': 0.5328934450232001, 'bagging_freq': 3, 'lambda_l1': 0.2062855283374326, 'lambda_l2': 3.076488416537764}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:30:21,944] Trial 217 finished with value: 0.06980559341443308 and parameters: {'objective': 'huber', 'learning_rate': 0.0026639731728500863, 'num_leaves': 95, 'max_depth': 8, 'feature_fraction': 0.9834121400982203, 'bagging_fraction': 0.4961418664025571, 'bagging_freq': 3, 'lambda_l1': 0.16020176451440582, 'lambda_l2': 4.062098534771731}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:30:53,450] Trial 218 finished with value: 0.06998143062493489 and parameters: {'objective': 'huber', 'learning_rate': 0.0022242365246702743, 'num_leaves': 90, 'max_depth': 8, 'feature_fraction': 0.9690271404523162, 'bagging_fraction': 0.46410623547154894, 'bagging_freq': 3, 'lambda_l1': 0.14545581104668662, 'lambda_l2': 4.632973091098939}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:31:23,686] Trial 219 finished with value: 0.0697817367870389 and parameters: {'objective': 'huber', 'learning_rate': 0.003224225127655081, 'num_leaves': 86, 'max_depth': 8, 'feature_fraction': 0.9418563389037997, 'bagging_fraction': 0.5779896568801276, 'bagging_freq': 3, 'lambda_l1': 0.12060177641088285, 'lambda_l2': 2.615924025031996}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:31:56,403] Trial 220 finished with value: 0.06979654733736644 and parameters: {'objective': 'huber', 'learning_rate': 0.0034308342355551477, 'num_leaves': 81, 'max_depth': 10, 'feature_fraction': 0.9420708533998768, 'bagging_fraction': 0.5836828155176943, 'bagging_freq': 3, 'lambda_l1': 0.11583901587383391, 'lambda_l2': 2.261597751558418}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:32:27,274] Trial 221 finished with value: 0.06994761104139241 and parameters: {'objective': 'huber', 'learning_rate': 0.0035243690645538634, 'num_leaves': 82, 'max_depth': 9, 'feature_fraction': 0.9302509051937342, 'bagging_fraction': 0.5737786190564991, 'bagging_freq': 3, 'lambda_l1': 0.11815669574000874, 'lambda_l2': 2.649099435957989}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:32:58,622] Trial 222 finished with value: 0.06981112218885488 and parameters: {'objective': 'huber', 'learning_rate': 0.0031922925188773007, 'num_leaves': 76, 'max_depth': 10, 'feature_fraction': 0.9405119195812318, 'bagging_fraction': 0.622108576136955, 'bagging_freq': 3, 'lambda_l1': 0.10906741968557353, 'lambda_l2': 2.3840221783170468}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:33:29,911] Trial 223 finished with value: 0.06990507262069136 and parameters: {'objective': 'huber', 'learning_rate': 0.004136819533372308, 'num_leaves': 80, 'max_depth': 9, 'feature_fraction': 0.9513975556328567, 'bagging_fraction': 0.6451136397702901, 'bagging_freq': 3, 'lambda_l1': 0.12802943615591822, 'lambda_l2': 3.4027764474538738}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:33:59,334] Trial 224 finished with value: 0.06976169378718573 and parameters: {'objective': 'huber', 'learning_rate': 0.003344509749969663, 'num_leaves': 87, 'max_depth': 8, 'feature_fraction': 0.9215044757153568, 'bagging_fraction': 0.5879005588547231, 'bagging_freq': 3, 'lambda_l1': 0.12119021517276567, 'lambda_l2': 1.920805649430187}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:34:27,088] Trial 225 finished with value: 0.06989470853371789 and parameters: {'objective': 'huber', 'learning_rate': 0.0037224819092567885, 'num_leaves': 89, 'max_depth': 8, 'feature_fraction': 0.9114177966126532, 'bagging_fraction': 0.5866175268280127, 'bagging_freq': 6, 'lambda_l1': 0.11948813976840826, 'lambda_l2': 1.8387574260758406}. Best is trial 124 with value: 0.06975258846629442.
# [I 2025-10-31 13:34:59,481] Trial 226 finished with value: 0.06972616206351998 and parameters: {'objective': 'huber', 'learning_rate': 0.003392790766844282, 'num_leaves': 93, 'max_depth': 8, 'feature_fraction': 0.927683602523946, 'bagging_fraction': 0.6118113338792335, 'bagging_freq': 3, 'lambda_l1': 0.1088394740974405, 'lambda_l2': 1.9588702643314242}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:35:23,452] Trial 227 finished with value: 0.06984474734644204 and parameters: {'objective': 'huber', 'learning_rate': 0.0035237383827323616, 'num_leaves': 97, 'max_depth': 7, 'feature_fraction': 0.9215373991574967, 'bagging_fraction': 0.6088210188791489, 'bagging_freq': 3, 'lambda_l1': 0.11409507889040324, 'lambda_l2': 2.025357647297006}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:35:54,261] Trial 228 finished with value: 0.06977066583114232 and parameters: {'objective': 'huber', 'learning_rate': 0.003346273499959129, 'num_leaves': 94, 'max_depth': 8, 'feature_fraction': 0.9039047796585835, 'bagging_fraction': 0.5994544610004544, 'bagging_freq': 3, 'lambda_l1': 0.12491874690181255, 'lambda_l2': 2.1897617923104598}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:36:23,820] Trial 229 finished with value: 0.06974992684208677 and parameters: {'objective': 'huber', 'learning_rate': 0.0029881474018883998, 'num_leaves': 94, 'max_depth': 8, 'feature_fraction': 0.887763767137966, 'bagging_fraction': 0.6340116764286998, 'bagging_freq': 3, 'lambda_l1': 0.13288981609321732, 'lambda_l2': 2.5137369383415598}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:36:47,175] Trial 230 finished with value: 0.07056984312904438 and parameters: {'objective': 'huber', 'learning_rate': 0.0030259684061655213, 'num_leaves': 94, 'max_depth': 7, 'feature_fraction': 0.8611285858523645, 'bagging_fraction': 0.6337419972695522, 'bagging_freq': 3, 'lambda_l1': 0.13180714159318724, 'lambda_l2': 1.8361343540924215}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:37:20,381] Trial 231 finished with value: 0.06975605224374745 and parameters: {'objective': 'huber', 'learning_rate': 0.002906746788129635, 'num_leaves': 98, 'max_depth': 8, 'feature_fraction': 0.8954273689158365, 'bagging_fraction': 0.6550768146332915, 'bagging_freq': 3, 'lambda_l1': 0.12191917472948154, 'lambda_l2': 2.5216863152470075}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:37:51,626] Trial 232 finished with value: 0.06975222733640284 and parameters: {'objective': 'huber', 'learning_rate': 0.0032222165557967194, 'num_leaves': 96, 'max_depth': 8, 'feature_fraction': 0.8929775204979212, 'bagging_fraction': 0.6383272165033662, 'bagging_freq': 3, 'lambda_l1': 0.10637308349650777, 'lambda_l2': 2.483742114908955}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:38:21,102] Trial 233 finished with value: 0.06985721980484247 and parameters: {'objective': 'huber', 'learning_rate': 0.003881677912220962, 'num_leaves': 99, 'max_depth': 8, 'feature_fraction': 0.8869553595051518, 'bagging_fraction': 0.681146797346003, 'bagging_freq': 3, 'lambda_l1': 0.10703453084712954, 'lambda_l2': 2.843359606084232}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:38:51,413] Trial 234 finished with value: 0.06973273418652372 and parameters: {'objective': 'huber', 'learning_rate': 0.0032813348375069114, 'num_leaves': 97, 'max_depth': 8, 'feature_fraction': 0.8991938024919781, 'bagging_fraction': 0.6166650428216472, 'bagging_freq': 3, 'lambda_l1': 0.12274892299598333, 'lambda_l2': 2.4106361202700546}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:39:31,074] Trial 235 finished with value: 0.07379572456090859 and parameters: {'objective': 'huber', 'learning_rate': 0.0010004763425527732, 'num_leaves': 99, 'max_depth': 8, 'feature_fraction': 0.87456068245348, 'bagging_fraction': 0.6542072057291843, 'bagging_freq': 3, 'lambda_l1': 0.1252205110092129, 'lambda_l2': 2.358309396476885}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:39:51,867] Trial 236 finished with value: 0.0706526797474089 and parameters: {'objective': 'huber', 'learning_rate': 0.003322899935581214, 'num_leaves': 95, 'max_depth': 6, 'feature_fraction': 0.843226946649778, 'bagging_fraction': 0.6423220262322809, 'bagging_freq': 3, 'lambda_l1': 0.10714025437507099, 'lambda_l2': 1.9415477287610416}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:40:15,439] Trial 237 finished with value: 0.06985167922056267 and parameters: {'objective': 'huber', 'learning_rate': 0.003628231149437307, 'num_leaves': 92, 'max_depth': 7, 'feature_fraction': 0.898040546217099, 'bagging_fraction': 0.6103520558553642, 'bagging_freq': 3, 'lambda_l1': 0.1261318546750583, 'lambda_l2': 2.261133581708872}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:40:46,295] Trial 238 finished with value: 0.0697412494946659 and parameters: {'objective': 'huber', 'learning_rate': 0.003352289316409281, 'num_leaves': 101, 'max_depth': 8, 'feature_fraction': 0.8996553085663009, 'bagging_fraction': 0.6596325048507651, 'bagging_freq': 3, 'lambda_l1': 0.10128671572294418, 'lambda_l2': 2.6322159831497394}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:41:14,395] Trial 239 finished with value: 0.07057456580434937 and parameters: {'objective': 'huber', 'learning_rate': 0.003276839170464137, 'num_leaves': 98, 'max_depth': 8, 'feature_fraction': 0.8625547044082654, 'bagging_fraction': 0.6567655686212039, 'bagging_freq': 3, 'lambda_l1': 0.10166726377207716, 'lambda_l2': 2.67155507181347}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:41:38,631] Trial 240 finished with value: 0.06984861238212135 and parameters: {'objective': 'huber', 'learning_rate': 0.003814418074429649, 'num_leaves': 105, 'max_depth': 7, 'feature_fraction': 0.8810229703347014, 'bagging_fraction': 0.670454326175967, 'bagging_freq': 3, 'lambda_l1': 0.1126825881620892, 'lambda_l2': 1.904066556357217}. Best is trial 226 with value: 0.06972616206351998.
# [I 2025-10-31 13:42:10,011] Trial 241 finished with value: 0.0697176349840275 and parameters: {'objective': 'huber', 'learning_rate': 0.0029464160908169745, 'num_leaves': 99, 'max_depth': 8, 'feature_fraction': 0.9008328604041503, 'bagging_fraction': 0.6159166679063629, 'bagging_freq': 3, 'lambda_l1': 0.12090096954640318, 'lambda_l2': 2.5213489576461514}. Best is trial 241 with value: 0.0697176349840275.
# [I 2025-10-31 13:42:41,415] Trial 242 finished with value: 0.06975931749095161 and parameters: {'objective': 'huber', 'learning_rate': 0.003129360712520123, 'num_leaves': 101, 'max_depth': 8, 'feature_fraction': 0.8924501836820402, 'bagging_fraction': 0.6265421189473653, 'bagging_freq': 3, 'lambda_l1': 0.11881519827327858, 'lambda_l2': 2.6280639504273875}. Best is trial 241 with value: 0.0697176349840275.
# [I 2025-10-31 13:43:13,804] Trial 243 finished with value: 0.06974858797232109 and parameters: {'objective': 'huber', 'learning_rate': 0.0033048378485536906, 'num_leaves': 102, 'max_depth': 8, 'feature_fraction': 0.894743436241022, 'bagging_fraction': 0.6265715259666221, 'bagging_freq': 3, 'lambda_l1': 0.10022494187522607, 'lambda_l2': 2.475142578634426}. Best is trial 241 with value: 0.0697176349840275.
# [I 2025-10-31 13:43:42,372] Trial 244 finished with value: 0.06988893997933866 and parameters: {'objective': 'huber', 'learning_rate': 0.004295088259413572, 'num_leaves': 102, 'max_depth': 8, 'feature_fraction': 0.8996501254685472, 'bagging_fraction': 0.6224073413751522, 'bagging_freq': 3, 'lambda_l1': 0.1022569952822914, 'lambda_l2': 2.511400401710256}. Best is trial 241 with value: 0.0697176349840275.
# [I 2025-10-31 13:44:08,173] Trial 245 finished with value: 0.06978678055307971 and parameters: {'objective': 'huber', 'learning_rate': 0.003388763092849556, 'num_leaves': 102, 'max_depth': 7, 'feature_fraction': 0.8912711262996349, 'bagging_fraction': 0.6297221534613557, 'bagging_freq': 3, 'lambda_l1': 0.11958472738776764, 'lambda_l2': 2.084244557423364}. Best is trial 241 with value: 0.0697176349840275.
# [I 2025-10-31 13:44:34,459] Trial 246 finished with value: 0.06979370474221398 and parameters: {'objective': 'huber', 'learning_rate': 0.003390240175664537, 'num_leaves': 105, 'max_depth': 7, 'feature_fraction': 0.8824136309250525, 'bagging_fraction': 0.6343199560525266, 'bagging_freq': 3, 'lambda_l1': 0.11599186934751608, 'lambda_l2': 1.591884945323706}. Best is trial 241 with value: 0.0697176349840275.
# [I 2025-10-31 13:44:56,902] Trial 247 finished with value: 0.07059765971622617 and parameters: {'objective': 'huber', 'learning_rate': 0.003678357697714566, 'num_leaves': 101, 'max_depth': 7, 'feature_fraction': 0.8568130044770776, 'bagging_fraction': 0.6183836707914346, 'bagging_freq': 3, 'lambda_l1': 0.12105264654880828, 'lambda_l2': 2.1840056380022057}. Best is trial 241 with value: 0.0697176349840275.
# [I 2025-10-31 13:45:24,140] Trial 248 finished with value: 0.06977558501393524 and parameters: {'objective': 'huber', 'learning_rate': 0.003181462368804175, 'num_leaves': 103, 'max_depth': 7, 'feature_fraction': 0.9022380618256587, 'bagging_fraction': 0.6680516966330472, 'bagging_freq': 2, 'lambda_l1': 0.10917820541130252, 'lambda_l2': 2.5322810180261235}. Best is trial 241 with value: 0.0697176349840275.
# [I 2025-10-31 13:45:44,068] Trial 249 finished with value: 0.06988218064529687 and parameters: {'objective': 'huber', 'learning_rate': 0.0032991340950264242, 'num_leaves': 103, 'max_depth': 6, 'feature_fraction': 0.8998109073030532, 'bagging_fraction': 0.6850776205134802, 'bagging_freq': 2, 'lambda_l1': 0.10862884167996133, 'lambda_l2': 1.7720316937206624}. Best is trial 241 with value: 0.0697176349840275.
# Best trial:
#   MAE:  0.0697176349840275
#   Best hyperparameters:  {'objective': 'huber', 'learning_rate': 0.0029464160908169745, 'num_leaves': 99, 'max_depth': 8, 'feature_fraction': 0.9008328604041503, 'bagging_fraction': 0.6159166679063629, 'bagging_freq': 3, 'lambda_l1': 0.12090096954640318, 'lambda_l2': 2.5213489576461514}

# %%
# Retrieve the best hyperparameters from the study.
best_params = study.best_trial.params
best_params['feature_contri']= [2.0, 0.1, 0.1, 1.0]
best_params['monotone_constraints']= '1,0,0,0'
best_params['monotone_constraints_method']= 'intermediate'

lgb_train = lgb.Dataset(X_train_val, y_train_val)
lgb_val = lgb.Dataset(X_train_val, y_train_val, reference=lgb_train)

# Train the final model.
final_model = lgb.train(
    best_params,
    lgb_train,
    num_boost_round=5000,             
    valid_sets=[lgb_val]
)

clear_output(wait=False)

# %%
final_model.save_model('ScenarioB_lgbm_final_model_001_CA.txt')

# %%
print("Features in order:", final_model.feature_name())
print("Monotone constraints:", final_model.params.get('monotone_constraints'))
# Out:
# Features in order: ['NDVI', 'Air_Temperature', 'relative_humidity', 'Downward_Short-Wave_Radiation_Flux']
# Monotone constraints: 1,0,0,0

# %%
final_model.params
# Out:
# {'objective': 'huber',
#  'learning_rate': 0.0029464160908169745,
#  'num_leaves': 99,
#  'max_depth': 8,
#  'feature_fraction': 0.9008328604041503,
#  'bagging_fraction': 0.6159166679063629,
#  'bagging_freq': 3,
#  'lambda_l1': 0.12090096954640318,
#  'lambda_l2': 2.5213489576461514,
#  'feature_contri': [2.0, 0.1, 0.1, 1.0],
#  'monotone_constraints': '1,0,0,0',
#  'monotone_constraints_method': 'intermediate',
#  'num_iterations': 5000}

# %%
final_model.feature_name()
# Out:
# ['NDVI',
#  'Air_Temperature',
#  'relative_humidity',
#  'Downward_Short-Wave_Radiation_Flux']

# %% [markdown]
# ## Model traning evaluation

# %%
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.io import output_notebook
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd

# %%
def predict_LGBM(model, X_df, y_df, prediction_col='ETa_predicted'):

    
    preds = model.predict(X_df)
    
    # Create a copy of the DataFrame and add the predictions column.
    df_with_preds = pd.concat([X_df, y_df], axis=1).copy()
    df_with_preds[prediction_col] = preds
    
    return df_with_preds

# %%
def plot_interactive_scatter_by_year(df, col1, col2):
    """
    Creates an interactive scatter plot using Bokeh.
    - X-axis represents col1.
    - Y-axis represents col2.
    - Dots are color-coded by year.
    - R² values for each year are displayed in the legend.
    - A 45-degree reference line is added.

    Parameters:
    df (pd.DataFrame): DataFrame with a datetime index.
    col1 (str): Column name for x-axis.
    col2 (str): Column name for y-axis.
    """

    # Ensure the index is in datetime format
    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index)

    # Extract year from index
    df['Year'] = df.index.year

    # Drop NaN values to avoid errors
    df = df.dropna(subset=[col1, col2])

    # Define colors for each year using a colormap
    unique_years = df['Year'].unique()
    colors = plt.cm.get_cmap('tab10', len(unique_years))  # Generate distinct colors

    # Initialize Bokeh figure
    p = figure(title=f"Interactive Scatter Plot: {col1} vs {col2}",
               x_axis_label=col1, y_axis_label=col2,
               width=500, height=500,
               tools="pan,box_zoom,wheel_zoom,reset,save",
               toolbar_location="above")

    # Determine the min and max values for equal scaling
    min_val = min(df[col1].min(), df[col2].min())
    max_val = max(df[col1].max(), df[col2].max())
    one_to_one_x = np.array([min_val, max_val])
    one_to_one_y = np.array([min_val, max_val])

    # Plot 45-degree reference line
    p.line(one_to_one_x, one_to_one_y, line_width=2, color="red", line_dash="dashed", legend_label="1:1 Line")

    # Store R² values for legend
    r2_legend_labels = []

    # Plot each year separately
    for i, year in enumerate(unique_years):
        df_year = df[df['Year'] == year]

        # Fit linear regression model and compute R²
        model = LinearRegression()
        x_values = df_year[col1].values.reshape(-1, 1)
        y_values = df_year[col2].values.reshape(-1, 1)
        model.fit(x_values, y_values)
        r2 = model.score(x_values, y_values)

        # Store R² value for legend
        r2_legend_labels.append(f"{year} (R² = {r2:.2f})")

        # Create data source for Bokeh
        source = ColumnDataSource(data={
            "x": df_year[col1],
            "y": df_year[col2],
            "time": df_year.index.strftime("%Y-%m-%d %H:%M"),  # Format datetime for tooltips
        })

        # Plot scatter points for each year
        p.scatter("x", "y", source=source, size=8, color='blue', alpha=0.6, legend_label=r2_legend_labels[-1])

    # Add hover tool
    hover = HoverTool(
        tooltips=[(col1, "@x"), (col2, "@y"), ("Time", "@time")],
        mode="mouse"
    )
    p.add_tools(hover)

    # Enable toggling elements by clicking the legend
    p.legend.click_policy = "hide"
    p.legend.background_fill_alpha = 0.5

    # Show the plot
    show(p)

# %%
final_model = lgb.Booster(model_file='ScenarioB_lgbm_final_model_001_CA.txt')

# %%
Bi1_AORC_train_file = os.path.join(os.path.dirname(os.getcwd()), '8_Data_prepration_prediction_phase',
                             'US_Bi1_Hourly_AORC_PSNDVI_ETa.csv')
Bi2_AORC_train_file = os.path.join(os.path.dirname(os.getcwd()), '8_Data_prepration_prediction_phase',
                             'US_Bi2_Hourly_AORC_PSNDVI_ETa.csv')
Tw3_AORC_train_file = os.path.join(os.path.dirname(os.getcwd()), '8_Data_prepration_prediction_phase',
                             'US_Tw3_Hourly_AORC_PSNDVI_ETa.csv')

# Load the data; ensure that the timestamp column is parsed as dates.
Bi1_AORC_train_df = pd.read_csv(Bi1_AORC_train_file, index_col=0, parse_dates=[0])
Bi2_AORC_train_df = pd.read_csv(Bi2_AORC_train_file, index_col=0, parse_dates=[0])
Tw3_AORC_train_df = pd.read_csv(Tw3_AORC_train_file, index_col=0, parse_dates=[0])

# Drop observations with nan NDVI values or ET_corr nan values
Bi1_AORC_train_df_filtered = Bi1_AORC_train_df[(Bi1_AORC_train_df['NDVI']>0) & (Bi1_AORC_train_df['ETa_corr']>0)]
Bi2_AORC_train_df_filtered = Bi2_AORC_train_df[(Bi2_AORC_train_df['NDVI']>0) & (Bi2_AORC_train_df['ETa_corr']>0)]
Tw3_AORC_train_df_filtered = Tw3_AORC_train_df[(Tw3_AORC_train_df['NDVI']>0) & (Tw3_AORC_train_df['ETa_corr']>0)]

# List of input feature columns
input_features_list = ['NDVI',
 'Air Temperature',
 'relative_humidity',
 'Downward Short-Wave Radiation Flux']

Bi1_X_test_train = Bi1_AORC_train_df_filtered[input_features_list].round(2)
Bi1_y_test_train = Bi1_AORC_train_df_filtered['ETa_corr'].round(3)

Bi2_X_test_train = Bi2_AORC_train_df_filtered[input_features_list].round(2)
Bi2_y_test_train = Bi2_AORC_train_df_filtered['ETa_corr'].round(3)

Tw3_X_test_train = Tw3_AORC_train_df_filtered[input_features_list].round(2)
Tw3_y_test_train = Tw3_AORC_train_df_filtered['ETa_corr'].round(3)

# %%
Bi1_df_test_w_preds = predict_LGBM(final_model, Bi1_X_test_train, Bi1_y_test_train, prediction_col='ETa_predicted')
plot_interactive_scatter_by_year(Bi1_df_test_w_preds, 'ETa_corr', 'ETa_predicted')

# %%
Bi2_df_test_w_preds = predict_LGBM(final_model, Bi2_X_test_train, Bi2_y_test_train, prediction_col='ETa_predicted')
plot_interactive_scatter_by_year(Bi2_df_test_w_preds, 'ETa_corr', 'ETa_predicted')

# %%
Tw3_df_test_w_preds = predict_LGBM(final_model, Tw3_X_test_train, Tw3_y_test_train, prediction_col='ETa_predicted')
plot_interactive_scatter_by_year(Tw3_df_test_w_preds, 'ETa_corr', 'ETa_predicted')

# %%
Bi1_df_test_w_preds.loc['2024']
# Out:
#                      NDVI  Air Temperature  relative_humidity  \
# 2024-02-05 06:00:00  0.70            11.35              82.94
# 2024-02-05 07:00:00  0.70            11.25              84.73
# 2024-02-05 08:00:00  0.70            11.35              84.21
# 2024-02-05 09:00:00  0.71            11.15              86.59
# 2024-02-05 10:00:00  0.71            11.55              85.53
# ...                   ...              ...                ...
# 2024-09-24 13:00:00  0.56            34.45              27.43
# 2024-09-24 14:00:00  0.55            36.15              23.62
# 2024-09-24 15:00:00  0.55            37.05              21.96
# 2024-09-24 17:00:00  0.57            36.25              23.18
# 2024-09-24 18:00:00  0.57            34.85              25.61
#
#                      Downward Short-Wave Radiation Flux  ETa_corr  \
# 2024-02-05 06:00:00                                 0.0     0.039
# 2024-02-05 07:00:00                                 0.0     0.027
# 2024-02-05 08:00:00                                85.7     0.061
# 2024-02-05 09:00:00                               181.8     0.115
# 2024-02-05 10:00:00                               284.0     0.134
# ...                                                 ...       ...
# 2024-09-24 13:00:00                               816.7     0.339
# 2024-09-24 14:00:00                               804.8     0.317
# 2024-09-24 15:00:00                               709.4     0.298
# 2024-09-24 17:00:00                               331.1     0.071
# 2024-09-24 18:00:00                               162.9     0.043
#
#                      ETa_predicted  Year
# 2024-02-05 06:00:00       0.033450  2024
# 2024-02-05 07:00:00       0.031689  2024
# 2024-02-05 08:00:00       0.046794  2024
# 2024-02-05 09:00:00       0.079137  2024
# 2024-02-05 10:00:00       0.127985  2024
# ...                            ...   ...
# 2024-09-24 13:00:00       0.383670  2024
# 2024-09-24 14:00:00       0.347036  2024
# 2024-09-24 15:00:00       0.401049  2024
# 2024-09-24 17:00:00       0.216225  2024
# 2024-09-24 18:00:00       0.102666  2024
#
# [2852 rows x 7 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from matplotlib.ticker import FormatStrFormatter

# Assuming df['actual'] and df['predicted'] exist
x = Bi1_df_test_w_preds.loc['2024']['ETa_corr'].values
y = Bi1_df_test_w_preds.loc['2024']['ETa_predicted'].values


# Stack them and calculate the point density
xy = np.vstack([x, y])
kde = gaussian_kde(xy)
kde.set_bandwidth(bw_method=0.3)
z = kde(xy)  # z is the density estimate
# Optional: sort so densest points are plotted last (on top)
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

# Error metrics
n = len(x)
r2 = r2_score(x, y)
mae = mean_absolute_error(x, y)
rmse = np.sqrt(mean_squared_error(x, y))
bias = np.mean(y - x)

# Plot
plt.figure(figsize=(4,3.2))
sc = plt.scatter(x, y, c=z, cmap='jet', s=12, vmin=1, vmax=8)
plt.colorbar(sc, label='Frequnecy')
plt.plot([0, 1.4], [0, 1.4], linestyle='--', color='black')

textstr = f'N = {n}\nMAE = {mae:.2f}\nRMSE = {rmse:.2f}\nBias = {bias:0.2f}'
plt.text(
    0.05, 0.95, textstr,
    transform=plt.gca().transAxes,  # Use axes coords (0–1)
    fontsize=9,
    verticalalignment='top',
    bbox=dict(boxstyle='round,pad=0.3', facecolor='white', edgecolor='gray',alpha=0.5)
)

# Set square plot area
plt.gca().set_aspect('equal', adjustable='box')
plt.gca().xaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))

plt.xlabel('Observed ETa (mm/hr)')
plt.ylabel('Predicted ETa (mm/hr)')
plt.xlim(0,1.2)
plt.ylim(0,1.2)
plt.title('US-Bi1, 2024', fontsize=10)
xmin, xmax = plt.gca().get_xlim()
ymin, ymax = plt.gca().get_ylim()

N = 7   # number of ticks

plt.xticks(np.linspace(xmin, xmax, N))
plt.yticks(np.linspace(ymin, ymax, N))
#plt.legend()
plt.tight_layout()
plt.savefig('US_Bi1_2024_Actual_vs_Predcited_ETa_plot_with_colorbar.png', dpi=300, transparent=True)
plt.show()
